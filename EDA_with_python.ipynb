# %% [markdown]
# <a href="https://colab.research.google.com/github/tahura-sh/Maching-Learning/blob/main/EDA_with_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('US_Accidents_March23.csv')
pd.set_option('display.max_columns',None)
data.head(5)
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  \
# 0  39.865147 -84.058723      NaN      NaN          0.01
# 1  39.928059 -82.831184      NaN      NaN          0.01
# 2  39.063148 -84.032608      NaN      NaN          0.01
# 3  39.747753 -84.205582      NaN      NaN          0.01
# 4  39.627781 -84.188354      NaN      NaN          0.01
#
#                                          Description  \
# 0  Right lane blocked due to accident on I-70 Eas...
# 1  Accident on Brice Rd at Tussing Rd. Expect del...
# ...

# %%
data.drop(['End_Lat','End_Lng'],axis=1,inplace=True)
data.head(3)
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
#
#    Start_Lat  Start_Lng  Distance(mi)  \
# 0  39.865147 -84.058723          0.01
# 1  39.928059 -82.831184          0.01
# 2  39.063148 -84.032608          0.01
#
#                                          Description          Street  \
# 0  Right lane blocked due to accident on I-70 Eas...          I-70 E
# 1  Accident on Brice Rd at Tussing Rd. Expect del...        Brice Rd
# 2  Accident on OH-32 State Route 32 Westbound at ...  State Route 32
#
#            City      County State     Zipcode Country    Timezone  \
# 0        Dayton  Montgomery    OH       45424      US  US/Eastern
# 1  Reynoldsburg    Franklin    OH  43068-3402      US  US/Eastern
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'Distance(mi)', 'Description', 'Street', 'City', 'County',
#        'State', 'Zipcode', 'Country', 'Timezone', 'Airport_Code',
#        'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
data.shape
# Out:
# (11241, 44)

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# Precipitation(in)        9685
# Wind_Chill(F)            9629
# Wind_Speed(mph)          1985
# Humidity(%)               151
# Visibility(mi)            120
# Temperature(F)            112
# Weather_Condition         105
# Pressure(in)               58
# Wind_Direction             53
# Weather_Timestamp          53
# Timezone                    2
# Airport_Code                2
# Zipcode                     2
# Give_Way                    1
# Junction                    1
# Bump                        1
# No_Exit                     1
# Railway                     1
# Roundabout                  1
# Station                     1
# Stop                        1
# Traffic_Calming             1
# Traffic_Signal              1
# Turning_Loop                1
# Sunrise_Sunset              1
# Civil_Twilight              1
# Nautical_Twilight           1
# Crossing                    1
# Astronomical_Twilight       1
# Amenity                     1
# Country                     1
# ...

# %%
#for filling null values
data['Wind_Chill(F)'].fillna(data['Wind_Chill(F)'].mean(),inplace=True)
data['Humidity(%)'].fillna(data['Humidity(%)'].mean(),inplace=True)
data['Pressure(in)'].fillna(data['Pressure(in)'].mean(),inplace=True)
data.head(3)
# Out:
# <ipython-input-10-ca60637a6c02>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Wind_Chill(F)'].fillna(data['Wind_Chill(F)'].mean(),inplace=True)
# <ipython-input-10-ca60637a6c02>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11241 entries, 0 to 11240
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     11241 non-null  object
#  1   Source                 11241 non-null  object
#  2   Severity               11241 non-null  int64
#  3   Start_Time             11241 non-null  object
#  4   End_Time               11241 non-null  object
#  5   Start_Lat              11241 non-null  float64
#  6   Start_Lng              11241 non-null  float64
#  7   Distance(mi)           11241 non-null  float64
#  8   Description            11241 non-null  object
#  9   Street                 11240 non-null  object
#  10  City                   11240 non-null  object
#  11  County                 11240 non-null  object
#  12  State                  11240 non-null  object
#  13  Zipcode                11239 non-null  object
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# changing data 'types of the columns End-time to extract day,month ,year and other details
data['End_Time']=data['End_Time'].astype(str).str.replace(r'\.\d+','',regex=True)
data['End_Time']=pd.to_datetime(data['End_Time'],format='%Y-%m-%d %H:%M:%S')
data['Year']=data['End_Time'].dt.year
data['Month']=data['End_Time'].dt.month
data['Day']=data["End_Time"].dt.day
data['Hour']=data['End_Time'].dt.hour
data['Minute']=data["End_Time"].dt.minute
data['Second']=data['End_Time'].dt.second
data['Date']=data['End_Time'].dt.date
data['Time']=data['End_Time'].dt.time

# %%
data['concatination'] = data['Temperature(F)'].astype(str) + ' ' + data['Nautical_Twilight']
data['concatination']
# Out:
# 0        36.9 Night
# 1        37.9 Night
# 2          36.0 Day
# 3          35.1 Day
# 4          36.0 Day
#             ...
# 11236      50.0 Day
# 11237      46.0 Day
# 11238    50.0 Night
# 11239    45.0 Night
# 11240           NaN
# Name: concatination, Length: 11241, dtype: object

# %%
data.describe()
# Out:
#            Severity                       End_Time     Start_Lat  \
# count  11241.000000                          11241  11241.000000
# mean       2.396673  2016-10-01 22:53:32.826883584     38.110141
# min        1.000000            2016-02-08 06:37:59     36.352592
# 25%        2.000000            2016-07-12 12:58:27     37.639637
# 50%        2.000000            2016-12-05 10:10:19     37.952530
# 75%        3.000000            2016-12-23 18:16:38     38.563847
# max        4.000000            2017-01-15 19:30:29     41.428753
# std        0.491406                            NaN      0.730690
#
#           Start_Lng  Distance(mi)  Temperature(F)  Wind_Chill(F)  \
# count  11241.000000  11241.000000    11129.000000   11241.000000
# mean    -119.350111      0.021485       58.736562      33.808623
# min     -123.810753      0.000000        3.900000      -8.400000
# 25%     -122.166779      0.000000       48.000000      33.808623
# ...

# %%
print(f'SEVERITY:{data.Severity.count()}')
print(f'Precipitation(in):{data["Precipitation(in)"].count()}')
print(f'Temperature(F):{data["Temperature(F)"].count()}')
# Out:
# SEVERITY:11241
# Precipitation(in):1556
# Temperature(F):11129

# %%
print(f'SEVERITY:{data.Severity.nunique()}')
print(f'Precipitation(in):{data["Precipitation(in)"].nunique()}')
print(f'Temperature(F):{data["Temperature(F)"].nunique()}')
# Out:
# SEVERITY:4
# Precipitation(in):33
# Temperature(F):252

# %%
print(f'SEVERITY:{data.Severity.dtype}')
print(f'Precipitation(in):{data["Precipitation(in)"].dtype}')
print(f'Temperature(F):{data["Temperature(F)"].dtype}')
# Out:
# SEVERITY:int64
# Precipitation(in):float64
# Temperature(F):float64

# %%
print(f'SEVERITY:{pd.api.types.is_numeric_dtype(data.Severity)}')
print(f'Precipitation(in):{pd.api.types.is_numeric_dtype(data["Precipitation(in)"])}')
print(f'Temperature(F):{pd.api.types.is_numeric_dtype(data["Temperature(F)"])}')
# Out:
# SEVERITY:True
# Precipitation(in):True
# Temperature(F):True

# %%
data.nunique()
# Out:
# ID                       11241
# Source                       2
# Severity                     4
# Start_Time               11147
# End_Time                 11157
# Start_Lat                 6955
# Start_Lng                 6845
# Distance(mi)                54
# Description               9438
# Street                    2426
# City                       413
# County                      64
# State                        3
# Zipcode                   2434
# Country                      1
# Timezone                     2
# Airport_Code                72
# Weather_Timestamp         6414
# Temperature(F)             252
# Wind_Chill(F)              260
# Humidity(%)                 94
# Pressure(in)               124
# Visibility(mi)              23
# Wind_Direction              20
# Wind_Speed(mph)             33
# Precipitation(in)           33
# Weather_Condition           25
# Amenity                      2
# Bump                         2
# Crossing                     2
# ...

# %%
num_cols= data.select_dtypes(include='number').columns.tolist()
num_cols
# Out:
# ['Severity',
#  'Start_Lat',
#  'Start_Lng',
#  'Distance(mi)',
#  'Temperature(F)',
#  'Wind_Chill(F)',
#  'Humidity(%)',
#  'Pressure(in)',
#  'Visibility(mi)',
#  'Wind_Speed(mph)',
#  'Precipitation(in)',
#  'Year',
#  'Month',
#  'Day',
#  'Hour',
#  'Minute',
#  'Second']

# %%
num_data = data[['Severity',
'Start_Lat',
'Start_Lng',
'Distance(mi)',
'Temperature(F)',
'Wind_Chill(F)',
'Humidity(%)',
'Pressure(in)',
'Visibility(mi)',
'Wind_Speed(mph)',
'Precipitation(in)',
'Year',
'Month',
'Day',
'Hour',
'Minute',
'Second']]
plt.figure(figsize=(10,8))
correlation_matrix= num_data.corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='0.2f')
plt.title('Correlation matrix for numeric columns')
plt.show()
